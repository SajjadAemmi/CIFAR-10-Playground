# %% [markdown]
# CIFAR-10 classification

# %% [markdown]
# Changelog
#
# version 1
# - Model input layed changed
# - Split train data to train/val data
# - epochs = 20

# %%
import tensorflow as tf

# %% [markdown]
# Dataset

# %%
dataset = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = dataset.load_data()

# %%
print(f"x_train:", "Shape", x_train.shape, ", Data Type", x_train.dtype, ", Min", x_train.min(), ", Max", x_train.max())
print(f"y_train:", "Shape", y_train.shape, ", Data Type", y_train.dtype, ", Min", y_train.min(), ", Max", y_train.max())
print(f"x_test:", "Shape", x_test.shape, ", Data Type", x_test.dtype, ", Min", x_test.min(), ", Max", x_test.max())
print(f"y_test:", "Shape", y_test.shape, ", Data Type", y_test.dtype, ", Min", y_test.min(), ", Max", y_test.max())
# Out:
# x_train: Shape (50000, 32, 32, 3) , Data Type uint8 , Min 0 , Max 255
# y_train: Shape (50000, 1) , Data Type uint8 , Min 0 , Max 9
# x_test: Shape (10000, 32, 32, 3) , Data Type uint8 , Min 0 , Max 255
# y_test: Shape (10000, 1) , Data Type uint8 , Min 0 , Max 9

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
print(f"x_train:", "Shape", x_train.shape, ", Data Type", x_train.dtype, ", Min", x_train.min(), ", Max", x_train.max())
print(f"x_test:", "Shape", x_test.shape, ", Data Type", x_test.dtype, ", Min", x_test.min(), ", Max", x_test.max())
# Out:
# x_train: Shape (50000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0
# x_test: Shape (10000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0

# %%
# Split train data to train/val data
x_train, x_val = x_train[:45000], x_train[45000:]
y_train, y_val = y_train[:45000], y_train[45000:]

# %%
print(f"x_train:", "Shape", x_train.shape, ", Data Type", x_train.dtype, ", Min", x_train.min(), ", Max", x_train.max())
print(f"y_train:", "Shape", y_train.shape, ", Data Type", y_train.dtype, ", Min", y_train.min(), ", Max", y_train.max())
print(f"x_val:", "Shape", x_val.shape, ", Data Type", x_val.dtype, ", Min", x_val.min(), ", Max", x_val.max())
print(f"y_val:", "Shape", y_val.shape, ", Data Type", y_val.dtype, ", Min", y_val.min(), ", Max", y_val.max())
# Out:
# x_train: Shape (45000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0
# y_train: Shape (45000, 1) , Data Type uint8 , Min 0 , Max 9
# x_val: Shape (5000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0
# y_val: Shape (5000, 1) , Data Type uint8 , Min 0 , Max 9

# %% [markdown]
# Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((32, 32, 3)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 394,634 (1.51 MB)
#  Trainable params: 394,634 (1.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

# %%
model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=20)
# Out:
# Epoch 1/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.2036 - loss: 2.1307 - val_accuracy: 0.2634 - val_loss: 1.9389
# Epoch 2/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.2593 - loss: 1.9615 - val_accuracy: 0.3178 - val_loss: 1.8753
# Epoch 3/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2793 - loss: 1.9246 - val_accuracy: 0.3094 - val_loss: 1.8703
# Epoch 4/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2922 - loss: 1.9061 - val_accuracy: 0.3512 - val_loss: 1.8022
# Epoch 5/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2977 - loss: 1.8962 - val_accuracy: 0.3294 - val_loss: 1.8224
# Epoch 6/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3012 - loss: 1.8954 - val_accuracy: 0.3466 - val_loss: 1.8117
# Epoch 7/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3035 - loss: 1.8840 - val_accuracy: 0.3542 - val_loss: 1.8002
# Epoch 8/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3107 - loss: 1.8715 - val_accuracy: 0.3524 - val_loss: 1.7944
# Epoch 9/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3102 - loss: 1.8670 - val_accuracy: 0.3494 - val_loss: 1.8121
# Epoch 10/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3132 - loss: 1.8738 - val_accuracy: 0.3662 - val_loss: 1.7842
# Epoch 11/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3218 - loss: 1.8633 - val_accuracy: 0.3448 - val_loss: 1.8368
# Epoch 12/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3174 - loss: 1.8639 - val_accuracy: 0.3626 - val_loss: 1.8008
# Epoch 13/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3220 - loss: 1.8575 - val_accuracy: 0.3656 - val_loss: 1.7748
# Epoch 14/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3239 - loss: 1.8539 - val_accuracy: 0.3660 - val_loss: 1.7920
# Epoch 15/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3252 - loss: 1.8536 - val_accuracy: 0.3606 - val_loss: 1.7748
# Epoch 16/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3235 - loss: 1.8541 - val_accuracy: 0.3450 - val_loss: 1.8204
# Epoch 17/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3226 - loss: 1.8503 - val_accuracy: 0.3688 - val_loss: 1.7736
# Epoch 18/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3243 - loss: 1.8472 - val_accuracy: 0.3650 - val_loss: 1.7670
# Epoch 19/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3298 - loss: 1.8481 - val_accuracy: 0.3776 - val_loss: 1.7606
# Epoch 20/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3219 - loss: 1.8460 - val_accuracy: 0.3672 - val_loss: 1.7883

# %%
model.evaluate(x_test,  y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3691 - loss: 1.7727
# [1.7761449813842773, 0.35989999771118164]
