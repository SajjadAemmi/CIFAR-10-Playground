# %% [markdown]
# CIFAR-10 classification

# %% [markdown]
# Changelog
#
# version 3
# - MLP model changed to CNN model
# - Add plots

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset

# %%
dataset = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = dataset.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 39s 0us/step

# %%
print(f"x_train:", "Shape", x_train.shape, ", Data Type", x_train.dtype, ", Min", x_train.min(), ", Max", x_train.max())
print(f"y_train:", "Shape", y_train.shape, ", Data Type", y_train.dtype, ", Min", y_train.min(), ", Max", y_train.max())
print(f"x_test:", "Shape", x_test.shape, ", Data Type", x_test.dtype, ", Min", x_test.min(), ", Max", x_test.max())
print(f"y_test:", "Shape", y_test.shape, ", Data Type", y_test.dtype, ", Min", y_test.min(), ", Max", y_test.max())
# Out:
# x_train: Shape (50000, 32, 32, 3) , Data Type uint8 , Min 0 , Max 255
# y_train: Shape (50000, 1) , Data Type uint8 , Min 0 , Max 9
# x_test: Shape (10000, 32, 32, 3) , Data Type uint8 , Min 0 , Max 255
# y_test: Shape (10000, 1) , Data Type uint8 , Min 0 , Max 9

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
print(f"x_train:", "Shape", x_train.shape, ", Data Type", x_train.dtype, ", Min", x_train.min(), ", Max", x_train.max())
print(f"x_test:", "Shape", x_test.shape, ", Data Type", x_test.dtype, ", Min", x_test.min(), ", Max", x_test.max())
# Out:
# x_train: Shape (50000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0
# x_test: Shape (10000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %%
print(f"y_train:", "Shape", y_train.shape, ", Data Type", y_train.dtype, ", Min", y_train.min(), ", Max", y_train.max())
print(f"y_test:", "Shape", y_test.shape, ", Data Type", y_test.dtype, ", Min", y_test.min(), ", Max", y_test.max())
# Out:
# y_train: Shape (50000, 10) , Data Type float64 , Min 0.0 , Max 1.0
# y_test: Shape (10000, 10) , Data Type float64 , Min 0.0 , Max 1.0

# %%
# Split train data to train/val data
x_train, x_val = x_train[:45000], x_train[45000:]
y_train, y_val = y_train[:45000], y_train[45000:]

# %%
print(f"x_train:", "Shape", x_train.shape, ", Data Type", x_train.dtype, ", Min", x_train.min(), ", Max", x_train.max())
print(f"y_train:", "Shape", y_train.shape, ", Data Type", y_train.dtype, ", Min", y_train.min(), ", Max", y_train.max())
print(f"x_val:", "Shape", x_val.shape, ", Data Type", x_val.dtype, ", Min", x_val.min(), ", Max", x_val.max())
print(f"y_val:", "Shape", y_val.shape, ", Data Type", y_val.dtype, ", Min", y_val.min(), ", Max", y_val.max())
# Out:
# x_train: Shape (45000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0
# y_train: Shape (45000, 10) , Data Type float64 , Min 0.0 , Max 1.0
# x_val: Shape (5000, 32, 32, 3) , Data Type float64 , Min 0.0 , Max 1.0
# y_val: Shape (5000, 10) , Data Type float64 , Min 0.0 , Max 1.0

# %% [markdown]
# Model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((32, 32, 3)),
    tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 156,074 (609.66 KB)
#  Trainable params: 156,074 (609.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy'])

# %%
epochs = 20
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=epochs)
# Out:
# Epoch 1/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.1981 - loss: 2.1739 - val_accuracy: 0.3022 - val_loss: 1.9242
# Epoch 2/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3792 - loss: 1.7301 - val_accuracy: 0.4210 - val_loss: 1.5833
# Epoch 3/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4588 - loss: 1.5146 - val_accuracy: 0.4590 - val_loss: 1.4840
# Epoch 4/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4918 - loss: 1.4079 - val_accuracy: 0.4848 - val_loss: 1.4142
# Epoch 5/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5309 - loss: 1.3183 - val_accuracy: 0.4784 - val_loss: 1.4547
# Epoch 6/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5525 - loss: 1.2580 - val_accuracy: 0.4806 - val_loss: 1.4466
# Epoch 7/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5746 - loss: 1.1902 - val_accuracy: 0.4762 - val_loss: 1.4712
# Epoch 8/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6000 - loss: 1.1287 - val_accuracy: 0.5172 - val_loss: 1.3603
# Epoch 9/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6177 - loss: 1.0860 - val_accuracy: 0.6114 - val_loss: 1.1234
# Epoch 10/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6372 - loss: 1.0252 - val_accuracy: 0.5236 - val_loss: 1.4007
# Epoch 11/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6568 - loss: 0.9855 - val_accuracy: 0.6118 - val_loss: 1.1055
# Epoch 12/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6699 - loss: 0.9440 - val_accuracy: 0.6344 - val_loss: 1.0597
# Epoch 13/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6794 - loss: 0.9073 - val_accuracy: 0.6440 - val_loss: 1.0478
# Epoch 14/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6967 - loss: 0.8662 - val_accuracy: 0.6486 - val_loss: 1.0400
# Epoch 15/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7079 - loss: 0.8386 - val_accuracy: 0.6416 - val_loss: 1.0450
# Epoch 16/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7215 - loss: 0.8038 - val_accuracy: 0.4952 - val_loss: 1.7846
# Epoch 17/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7295 - loss: 0.7725 - val_accuracy: 0.6060 - val_loss: 1.1912
# Epoch 18/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7416 - loss: 0.7420 - val_accuracy: 0.6680 - val_loss: 0.9767
# Epoch 19/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7508 - loss: 0.7141 - val_accuracy: 0.6370 - val_loss: 1.1204
# Epoch 20/20
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7622 - loss: 0.6855 - val_accuracy: 0.5848 - val_loss: 1.3319

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(x_test,  y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5841 - loss: 1.3247
# [1.3465427160263062, 0.5792999863624573]
